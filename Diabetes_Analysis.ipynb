# %%
import numpy as py

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data=pd.read_csv("/content/diabetes.csv")

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.shape
# Out:
# (768, 9)

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
x=data['BloodPressure']
plt.plot(x)

# %%
a=data['Glucose']
b=data['BMI']
plt.scatter(a,b)

# %%
x=data['BloodPressure']
plt.bar(x,height=15,width=200,color='red')
# Out:
# <BarContainer object of 768 artists>

# %%
x=data['Glucose']
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7a7041eadcf0>,
# ...
#  [Text(1.099986207302363, 0.005508515640637803, ''),
#   Text(1.0999085948579037, 0.014180372269863677, ''),
#   Text(1.0997347846673413, 0.024153744899635246, ''),
#   Text(1.0994659144851398, 0.034273938865493944, ''),
#   Text(1.0991716783526928, 0.04268045814332954, ''),
#   Text(1.0987660386786011, 0.05208831199544575, ''),
#   Text(1.0984004491793988, 0.0592996900708191, ''),
#   Text(1.0979897805249033, 0.06647136122327452, ''),
#   Text(1.0972268777858931, 0.07805881541645847, ''),
#   Text(1.096311299443135, 0.09000852578119999, ''),
#   Text(1.095560945054012, 0.09872292374297004, ''),
#   Text(1.0945838560721655, 0.10902376817093205, ''),
#   Text(1.0933923127993568, 0.12038791596864637, ''),
#   Text(1.091988904040351, 0.132515031044608, ''),
#   Text(1.0903184122315757, 0.14562197618771724, ''),
#   Text(1.0889636064932942, 0.1554292885305673, ''),
#   Text(1.0877874990656315, 0.1634575078622541, ''),
# ...

# %%
a=data['Age']
plt.hist(a)
# Out:
# (array([300., 157.,  92.,  86.,  52.,  34.,  26.,  16.,   4.,   1.]),
#  array([21., 27., 33., 39., 45., 51., 57., 63., 69., 75., 81.]),
#  <BarContainer object of 10 artists>)

# %%
sns.lineplot(X=data['BMI'])
# Out:
# <Axes: >

# %%
sns.scatterplot(x=data['Glucose'],y=data['Age'])
# Out:
# <Axes: xlabel='Glucose', ylabel='Age'>

# %%
sns.boxplot(x=data['Insulin'])
# Out:
# <Axes: xlabel='Insulin'>

# %%
sns.barplot(x=data['BloodPressure'],y=data['Pregnancies'])
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Pregnancies'>

# %%
sns.displot(x=data['Pregnancies'])

# %%
sns.countplot(x=data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.pairplot(data,hue='Age')

# %%
x=data.drop('Outcome',axis=1)
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=data['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.40,random_state=0)

# %%
x_train.shape
# Out:
# (460, 8)

# %%
x_test.shape
# Out:
# (308, 8)

# %%
y_train.shape
# Out:
# (460,)

# %%
y_test.shape
# Out:
# (308,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
a= DecisionTreeClassifier()
a.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=a.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7012987012987013

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[161,  48],
#        [ 44,  55]])

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
graphviz.Source(export_graphviz(a,feature_names=x.columns,filled=True))
